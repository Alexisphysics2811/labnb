# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Experimental Data here:

x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

if x.size == y.size:
    print("All good!")
# Out:
# All good!

# %%
# Create a plot
plt.figure(figsize=(10, 6))

# Plot mass_vector_merged
plt.plot(x, y, label='label', color='blue', marker='o')

# Adding titles and labels
plt.title('Title')
plt.xlabel('x')
plt.ylabel('y')

# Show legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
# Perform linear regression using scipy
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Generate predictions using the slope and intercept
y_pred = slope * x + intercept

# Plot the regression line
plt.plot(x, y_pred, color='blue', label='label')

# Print the regression statistics
print(f"Slope = {slope:.4f}, Intercept = {intercept:.4f}, R-squared = {r_value**2:.4f}")
# Out:
# Slope = 1.0000, Intercept = 0.0000, R-squared = 1.0000

# %%
# Create a plot
plt.figure(figsize=(10, 6))

# Plot experimental data
plt.plot(x, y, label='label', color='blue', marker='o')

# Plot the regression line
plt.plot(x, y_pred, color='red')

# Adding titles and labels
plt.title('Title')
plt.xlabel('x')
plt.ylabel('y')

# Show legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()
