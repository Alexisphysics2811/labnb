# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Termistor Data ---
# Sensor Voltage averages and standard deviations.
# Note: np.nan is used where standard deviation was reported as 'nan'
termistor_voltage = [
    1.491, 1.491, 1.491, 1.496, 1.496, 1.496, 1.496, 1.496, 1.496,
    1.622, 1.633, 1.639, 1.643, 1.643, 1.643, 1.643,
    1.368, 1.364, 1.359, 1.358, 1.358, 1.359, 1.358, 1.358
]
termistor_std = [
    0.001, 0.000, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001,
    0.005, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
    0.001, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001
]

# Create x-axis indices for Termistor measurements
x_termistor = np.arange(1, len(termistor_voltage) + 1)

# --- Fotoresistance Data ---
fotores_voltage = [
    3.134, 3.239, 3.275, 3.014, 3.136, 3.221, 3.713, 4.905, 4.929,
    4.923, 4.935, 4.931, 3.692, 2.992, 1.089, 0.995, 0.926, 0.637, 0.516
]
fotores_std = [
    0.044, 0.007, 0.044, 0.018, 0.069, 0.009, 0.613, 0.014, 0.004,
    0.003, 0.006, 0.004, 0.871, 0.004, 0.025, 0.011, 0.099, 0.011, 0.015
]

# Create x-axis indices for Fotoresistance measurements
x_fotores = np.arange(1, len(fotores_voltage) + 1)

# --- Plot Termistor Data ---
plt.figure(figsize=(10, 5))
plt.errorbar(x_termistor, termistor_voltage, yerr=termistor_std, fmt='-o', capsize=5, label='Termistor Voltage')
plt.title("Termistor Sensor Voltage Measurements")
plt.xlabel("Measurement Number")
plt.ylabel("Voltage (V)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# --- Plot Fotoresistance Data ---
plt.figure(figsize=(10, 5))
plt.errorbar(x_fotores, fotores_voltage, yerr=fotores_std, fmt='-o', capsize=5, label='Fotores Voltage', color='orange')
plt.title("Fotoresistance Sensor Voltage Measurements")
plt.xlabel("Measurement Number")
plt.ylabel("Voltage (V)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
